# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhatti12/learnpython/blob/main/Python_class03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bin(65)
# Out:
# '0b1000001'

# %%
print("Pakistan Zindabad!!")
# Out:
# Pakistan Zindabad!!

# %%
print(type('Helloworld'))
# Out:
# <class 'str'>

# %%
"FaRruKh".capitalize()
'Ali'.lower()
# Out:
# 'ali'

# %%
print("""Farrukh""")
# Out:
# Farrukh

# %%
print(type(13.3))
print(type(12+12j))
print(type("43"))
print(type(True))
print(type(3))
# Out:
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>

# %% [markdown]
# ***STATIC VS DYNAMIC TYPED Language***

# %%
print(type({1,2,3,4,5}))
# Out:
# <class 'set'>

# %%
print(type([1,2,3,4,5]))
# Out:
# <class 'list'>

# %%
print({"name":"Bhatti"})
# Out:
# {'name': 'Bhatti'}

# %% [markdown]
# ***Variables***
# 1) name
# 2) Operator
# 3) Value
#
# ````
#     python:
#     variable_name = 'value'
# ````
# Now workign with Type Hint
#
# ```
#     python:
#     variable_name: type = 'value'
# ```

# %%
#name         type   value
student_name: str = "Farrukh Bhatti"
print(student_name)
# Out:
# Farrukh Bhatti

# %%
student_first_name :  str = "Farrukh"
student_last_name : str = "Bhatti"
student_father_name :str = "Makhdoom Rasheed Ahmed Bhatti"
student_age : int = 46
student_contact : str = "Leuven"
student_email : str = "farrukh.bhatti@ymail.com"
student_is_pakistani : bool = True

print("student_first_name : " + student_first_name )
print("student_last_name : " + student_last_name )
print("student_father_name : " + student_father_name )
print("student_age : " + str(student_age) )
print("student_contact : " + student_contact )
print("student_email : " + student_email )
print("student_is_pakistani : " + str(student_is_pakistani) )
# Out:
# student_first_name : Farrukh
# student_last_name : Bhatti
# student_father_name : Makhdoom Rasheed Ahmed Bhatti
# student_age : 46
# student_contact : Leuven
# student_email : farrukh.bhatti@ymail.com
# student_is_pakistani : True

# %%
name_list : list = ["Farrukh", "Bhatti"]
print(name_list)
# Out:
# ['Farrukh', 'Bhatti']

# %%
student_card = """
***Student Card***
First Name : %s
Last Name : %s
Father Name : %s
Age : %d
Contact : %s
Email : %s
Is Pakistani : %s
""" % (student_first_name,student_last_name,student_father_name,student_age,student_contact,student_email,student_is_pakistani)
print(student_card)
# Out:
# ***Student Card***
# First Name : Farrukh
# Last Name : Bhatti
# Father Name : Makhdoom Rasheed Ahmed Bhatti
# Age : 46
# Contact : Leuven
# Email : farrukh.bhatti@ymail.com
# Is Pakistani : True

# %%
print("***Student Card***\nFirst Name : " + student_first_name + "\nLast Name : "+ student_last_name + "\nFather Name : " + student_father_name + "\nAge : " + str(student_age) + "\nContact : " + student_contact + "\nEmail : " + student_email + "\nIs Pakistani : " +  str(student_is_pakistani))
# Out:
# ***Student Card***
# First Name : Farrukh
# Last Name : Bhatti
# Father Name : Makhdoom Rasheed Ahmed Bhatti
# Age : 46
# Contact : Leuven
# Email : farrukh.bhatti@ymail.com
# Is Pakistani : True
