# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhatti12/learnpython/blob/main/Python_class08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import Any
data : list[Any] = ["Farrukh", "Rasheed", 30, "Msc", "A+"]

# %%
from typing import Any
data : dict[str, Any] = {
    "name" : "Farrukh",
    "surname" : "Rasheed",
    "age" : 30,
    "degree" : "Msc",
    "grade" : "A+",
    "subjects" : {"Math" : 100, "Logic" : 10}

}

print(data['subjects'].get('Math'))
# Out:
# 100
