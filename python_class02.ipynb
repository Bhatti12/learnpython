# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhatti12/learnpython/blob/main/python_class02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**class notes:**
#
# ipynb = Interactive Python Notebook
#
# **Running the cell:**
#
# *ctrl + enter*
#
# *alt + enter*
#
# **######Markdown cheetsheet**

# %%
print("Farrukh Bhatti")
# Out:
# Farrukh Bhatti

# %%
print("Testing")
# Out:
# Testing
